# %%
# Liam's script for looking at basic info about the data
import pandas as pd
import numpy as np
import os
import accessDB as db

# %%
# Read raw data in
df = db.filter(doGeoLoc=True)

# %%
# Number of rows
len(df.index)
# Out:
# 407646

# %%
# Number of unique call numbers
len(df['Call Number'].unique())
# Out:
# 302422

# %%
# Number of rows containing missing data
len(df[df.isnull().any(axis=1)].index)
# Out:
# 169483

# %%
# Number of addresses not containing "MKE"
len(df[df['Location'].str.contains('MKE') == False])
# Out:
# 9686

# %%
# Number of unique locations
len(df['Location'].value_counts())
# Out:
# 84518

# %%
# Top 10 locations (police stations etc)
df['Location'].value_counts().head(10)
# Out:
# 2333 N 49TH ST,MKE              10724
# 749 W STATE ST,MKE               9265
# 3626 W FOND DU LAC AV,MKE        9117
# 245 W LINCOLN AV,MKE             8494
# 2920 N VEL R PHILLIPS AV,MKE     8245
# 6929 W SILVER SPRING DR,MKE      7701
# 3006 S 27TH ST,MKE               7344
# 6680 N TEUTONIA AV,MKE           2944
# 4715 W VLIET ST,MKE              2391
# 949 N 9TH ST,MKE                 1773
# Name: Location, dtype: int64

# %%
# Number of instances of each nature
df['Nature of Call'].value_counts().head(10)
# Out:
# BUSINESS CHECK     41004
# TRAFFIC STOP       37830
# TRBL W/SUBJ        23217
# RETURN STATION     22884
# FOLLOW UP          15237
# PATROL             14107
# WELFARE CITIZEN    11926
# REPORTS            11747
# ACC PDO            11187
# POLICE ADMIN       10620
# Name: Nature of Call, dtype: int64

# %%
# Number of instances of each status
df['Status'].value_counts()
# Out:
# Service in Progress              143735
# Assignment Completed             134726
# Advised                           60117
# Unable to Locate Complainant      29045
# To be Filed                       14854
# City Citation(s) Issued           11767
# Advised/Referral                   7833
# Open Investigation                 3876
# No Prosecution                      463
# Cleared by Arrest                   432
# False Alarm                         301
# Filed Driver Exchange Report        291
# Referral                            109
# Patrol Request                       74
# False Alarm (Weather Related)        12
# State Citation(s) Issued             10
# Ordered to Appear                     1
# Name: Status, dtype: int64

# %%
# Number of instances of each police district
df['Police District'].value_counts()
# Out:
# 7       72980
# 3       68902
# 5       61841
# 4       57346
# 2       54015
# 6       45552
# 1       44355
# CITY      814
# SPD       743
# OCOE      540
# ?         263
# OUT       162
# SCD        45
# DPR        38
# FI         15
# CIB        12
# ICS3        9
# SID         3
# NLA         3
# NTF         2
# ICS1        2
# IFC         2
# TEU         2
# Name: Police District, dtype: int64

# %%
# Items with NLA police district (example)
df[df['Police District'] == 'NLA']
# Out:
#                                Call Number           Date/Time  \
# ID
# 182682688-Service in Progress    182682688 2018-09-25 21:17:22
# 183020910-Service in Progress    183020910 2018-10-29 10:56:08
# 183542300-Advised                183542300 2018-12-20 18:25:54
#
#                                                       Location  \
# ID
# 182682688-Service in Progress        6500-BLK S 27TH, FRANKLIN
# 183020910-Service in Progress  3128 GRAYDON AVE - EAST TROY WI
# 183542300-Advised                HAMPTON AT I43, MILWAUKEE, WI
#
#                               Police District  Nature of Call  \
# ID
# 182682688-Service in Progress             NLA  SPECIAL ASSIGN
# 183020910-Service in Progress             NLA   INVESTIGATION
# 183542300-Advised                         NLA    TRAFFIC STOP
#
#                                             Status Latitude Longitude
# ID
# 182682688-Service in Progress  Service in Progress      NaN       NaN
# 183020910-Service in Progress  Service in Progress  43.0113  -87.9584
# 183542300-Advised                          Advised      NaN       NaN

# %%
# Items originating from false alarms (example)
df[df['Status'] == 'Patrol Request']
# Out:
#                           Call Number           Date/Time  \
# ID
# 182552319-Patrol Request    182552319 2018-09-12 18:51:22
# 182571871-Patrol Request    182571871 2018-09-14 16:02:38
# 182592230-Patrol Request    182592230 2018-09-16 20:01:31
# 182592373-Patrol Request    182592373 2018-09-16 21:18:07
# 182601475-Patrol Request    182601475 2018-09-17 13:54:05
# 182602615-Patrol Request    182602615 2018-09-17 20:50:01
# 182641451-Patrol Request    182641451 2018-09-21 14:20:44
# 182641847-Patrol Request    182641847 2018-09-21 16:30:10
# 182642068-Patrol Request    182642068 2018-09-21 18:31:03
# 182650884-Patrol Request    182650884 2018-09-22 11:42:20
# 182701415-Patrol Request    182701415 2018-09-27 14:15:24
# 182722178-Patrol Request    182722178 2018-09-29 19:41:48
# 182741188-Patrol Request    182741188 2018-10-01 12:54:15
# 182771764-Patrol Request    182771764 2018-10-04 16:23:39
# 182782296-Patrol Request    182782296 2018-10-05 21:03:28
# 182790747-Patrol Request    182790747 2018-10-06 09:54:34
# 182800759-Patrol Request    182800759 2018-10-07 09:08:24
# 182800904-Patrol Request    182800904 2018-10-07 11:14:00
# 182801099-Patrol Request    182801099 2018-10-07 13:07:16
# 182810929-Patrol Request    182810929 2018-10-08 11:03:20
# 182831587-Patrol Request    182831587 2018-10-10 14:36:44
# 182832480-Patrol Request    182832480 2018-10-10 20:51:02
# 182841960-Patrol Request    182841960 2018-10-11 18:04:35
# 182851311-Patrol Request    182851311 2018-10-12 13:12:11
# 182882152-Patrol Request    182882152 2018-10-15 17:32:25
# 182891100-Patrol Request    182891100 2018-10-16 12:17:12
# 182901968-Patrol Request    182901968 2018-10-17 17:22:23
# 182911893-Patrol Request    182911893 2018-10-18 16:59:14
# 182942266-Patrol Request    182942266 2018-10-21 21:31:00
# 182981455-Patrol Request    182981455 2018-10-25 14:32:35
# ...                               ...                 ...
# 183220692-Patrol Request    183220692 2018-11-18 09:13:16
# 183221329-Patrol Request    183221329 2018-11-18 15:54:48
# 183221423-Patrol Request    183221423 2018-11-18 16:13:41
# 183221502-Patrol Request    183221502 2018-11-18 16:41:48
# 183221615-Patrol Request    183221615 2018-11-18 17:09:45
# 183222103-Patrol Request    183222103 2018-11-18 20:29:33
# 183222319-Patrol Request    183222319 2018-11-18 21:31:40
# 183251875-Patrol Request    183251875 2018-11-21 19:35:30
# 183252233-Patrol Request    183252233 2018-11-21 20:12:36
# 183301948-Patrol Request    183301948 2018-11-26 17:26:02
# 183482594-Patrol Request    183482594 2018-12-14 20:42:40
# 183491539-Patrol Request    183491539 2018-12-15 16:21:23
# 183501968-Patrol Request    183501968 2018-12-16 19:59:01
# 183512299-Patrol Request    183512299 2018-12-17 20:04:39
# 183642413-Patrol Request    183642413 2018-12-30 21:48:24
# 190012848-Patrol Request    190012848 2019-01-01 19:39:00
# 190081253-Patrol Request    190081253 2019-01-08 13:03:01
# 190102066-Patrol Request    190102066 2019-01-10 17:47:48
# 190111745-Patrol Request    190111745 2019-01-11 17:20:06
# 190121639-Patrol Request    190121639 2019-01-12 16:38:47
# 190162615-Patrol Request    190162615 2019-01-16 21:34:44
# 190172008-Patrol Request    190172008 2019-01-17 17:37:19
# 190180977-Patrol Request    190180977 2019-01-18 10:49:11
# 190221662-Patrol Request    190221662 2019-01-22 16:41:50
# 190231515-Patrol Request    190231515 2019-01-23 14:09:16
# 190320600-Patrol Request    190320600 2019-02-01 08:10:53
# 190420966-Patrol Request    190420966 2019-02-11 11:26:54
# 190441517-Patrol Request    190441517 2019-02-13 16:04:21
# 190471231-Patrol Request    190471231 2019-02-16 13:57:40
# 190502181-Patrol Request    190502181 2019-02-19 19:11:41
#
#                                                      Location Police District  \
# ID
# 182552319-Patrol Request  N 107TH ST / W SILVER SPRING DR,MKE               4
# 182571871-Patrol Request   N 53RD ST / W SILVER SPRING DR,MKE               4
# 182592230-Patrol Request       N WATER ST / E PLEASANT ST,MKE               1
# 182592373-Patrol Request               4007 W MEINECKE AV,MKE               3
# 182601475-Patrol Request                   7130 W MAIN ST,MKE               3
# 182602615-Patrol Request                    4448 S 1ST ST,MKE               6
# 182641451-Patrol Request     S 28TH ST / W FOREST HOME AV,MKE               2
# 182641847-Patrol Request               4455 W CONGRESS ST,MKE               7
# 182642068-Patrol Request             6540 N INDUSTRIAL RD,MKE               4
# 182650884-Patrol Request                1408 W MADISON ST,MKE               2
# 182701415-Patrol Request                   3410 N 96TH ST,MKE               7
# 182722178-Patrol Request                   5571 N 34TH ST,MKE               4
# 182741188-Patrol Request                 709 E CAPITOL DR,MKE               5
# 182771764-Patrol Request                   4720 N 37TH ST,MKE               7
# 182782296-Patrol Request                   5481 N 13TH ST,MKE               4
# 182790747-Patrol Request                   1326 S 36TH ST,MKE               2
# 182800759-Patrol Request                139 E KILBOURN AV,MKE               1
# 182800904-Patrol Request                   2844 N 82ND ST,MKE               7
# 182801099-Patrol Request                 7405 W LISBON AV,MKE               7
# 182810929-Patrol Request                 711 W CAPITOL DR,MKE               5
# 182831587-Patrol Request                   455 E OGDEN AV,MKE               1
# 182832480-Patrol Request                   4122 N 85TH ST,MKE               7
# 182841960-Patrol Request                2908 W VILLARD AV,MKE               4
# 182851311-Patrol Request         N 27TH ST / W CAPITOL DR,MKE               5
# 182882152-Patrol Request              500 W WASHINGTON ST,MKE               2
# 182891100-Patrol Request                3050 W FARDALE AV,MKE               6
# 182901968-Patrol Request                2139 S ALDRICH ST,MKE               6
# 182911893-Patrol Request                   3228 S 24TH ST,MKE               6
# 182942266-Patrol Request                   2492 S 13TH ST,MKE               2
# 182981455-Patrol Request                12500 W CARMEN AV,MKE               4
# ...                                                       ...             ...
# 183220692-Patrol Request                3415 S INDIANA AV,MKE               6
# 183221329-Patrol Request                   5810 S 15TH PL,MKE               6
# 183221423-Patrol Request                   4221 N 19TH ST,MKE               5
# 183221502-Patrol Request                   6517 N 81ST ST,MKE               4
# 183221615-Patrol Request               2112 E FERNWOOD AV,MKE               6
# 183222103-Patrol Request                 2504 W JUNEAU AV,MKE               3
# 183222319-Patrol Request                   4119 N 82ND ST,MKE               7
# 183251875-Patrol Request                   4190 N 15TH ST,MKE               5
# 183252233-Patrol Request               6915 W CONGRESS ST,MKE               7
# 183301948-Patrol Request                1900 E BENNETT AV,MKE               6
# 183482594-Patrol Request                  2300 W VOGEL AV,MKE               6
# 183491539-Patrol Request                   3756 N 88TH ST,MKE               7
# 183501968-Patrol Request               3719 W NATIONAL AV,MKE               2
# 183512299-Patrol Request           N 26TH ST / W STATE ST,MKE               3
# 183642413-Patrol Request                    3410 N 7TH ST,MKE               5
# 190012848-Patrol Request                2530 S BURRELL ST,MKE               6
# 190081253-Patrol Request                   2566 N 48TH ST,MKE               3
# 190102066-Patrol Request             W HOLT AV / S 1ST ST,MKE               6
# 190111745-Patrol Request                   3132 N 83RD ST,MKE               7
# 190121639-Patrol Request                   3570 S 19TH ST,MKE               6
# 190162615-Patrol Request                   1000 S 28TH ST,MKE               2
# 190172008-Patrol Request                   5220 N 54TH ST,MKE               4
# 190180977-Patrol Request                 1955 W PURDUE ST,MKE               7
# 190221662-Patrol Request               9838 W APPLETON AV,MKE               4
# 190231515-Patrol Request               8333 W APPLETON AV,MKE               7
# 190320600-Patrol Request                241 W EDGERTON AV,MKE               6
# 190420966-Patrol Request         S 15TH PL / W LINCOLN AV,MKE               2
# 190441517-Patrol Request                   6656 N 42ND ST,MKE               4
# 190471231-Patrol Request               2915 W HIGHLAND BL,MKE               3
# 190502181-Patrol Request      S 35TH ST / W GREENFIELD AV,MKE               2
#
#                             Nature of Call          Status Latitude Longitude
# ID
# 182552319-Patrol Request  RECKLESS VEHICLE  Patrol Request  43.1184  -88.0458
# 182571871-Patrol Request      DRUG DEALING  Patrol Request  43.1175  -87.9787
# 182592230-Patrol Request      DRUG DEALING  Patrol Request  43.0507   -87.906
# 182592373-Patrol Request  RECKLESS VEHICLE  Patrol Request  43.0618  -87.9652
# 182601475-Patrol Request    SUSP PERS/AUTO  Patrol Request  43.0263  -88.0019
# 182602615-Patrol Request         ADDL INFO  Patrol Request  42.9635  -87.9107
# 182641451-Patrol Request       TRBL W/SUBJ  Patrol Request  43.0001  -87.9493
# 182641847-Patrol Request   PROPERTY DAMAGE  Patrol Request      NaN       NaN
# 182642068-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 182650884-Patrol Request       TRBL W/SUBJ  Patrol Request  43.0113  -87.9584
# 182701415-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 182722178-Patrol Request       TRBL W/SUBJ  Patrol Request  43.1189  -87.9553
# 182741188-Patrol Request         ADDL INFO  Patrol Request  43.0881  -87.9021
# 182771764-Patrol Request       TRBL W/SUBJ  Patrol Request   43.103  -87.9587
# 182782296-Patrol Request             THEFT  Patrol Request   43.117  -87.9267
# 182790747-Patrol Request       TRBL W/SUBJ  Patrol Request  43.0171  -87.9585
# 182800759-Patrol Request             THEFT  Patrol Request  43.0417  -87.9107
# 182800904-Patrol Request             ENTRY  Patrol Request      NaN       NaN
# 182801099-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 182810929-Patrol Request       TRBL W/SUBJ  Patrol Request   43.089  -87.9199
# 182831587-Patrol Request       TRBL W/SUBJ  Patrol Request  43.0479  -87.9066
# 182832480-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 182841960-Patrol Request       TRBL W/SUBJ  Patrol Request  43.1121  -87.9493
# 182851311-Patrol Request       ENTRY AUTOS  Patrol Request  43.0898   -87.947
# 182882152-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 182891100-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 182901968-Patrol Request    SUSP PERS/AUTO  Patrol Request      NaN       NaN
# 182911893-Patrol Request       TRBL W/SUBJ  Patrol Request  42.9859  -87.9442
# 182942266-Patrol Request       TRBL W/SUBJ  Patrol Request  42.9993  -87.9281
# 182981455-Patrol Request       TRBL W/SUBJ  Patrol Request  43.1232  -88.0681
# ...                                    ...             ...      ...       ...
# 183220692-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 183221329-Patrol Request    SUSP PERS/AUTO  Patrol Request      NaN       NaN
# 183221423-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 183221502-Patrol Request       TRBL W/SUBJ  Patrol Request  43.1364   -88.012
# 183221615-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 183222103-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 183222319-Patrol Request       ENTRY AUTOS  Patrol Request  43.0922  -88.0153
# 183251875-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 183252233-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 183301948-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 183482594-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 183491539-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 183501968-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 183512299-Patrol Request       TRBL W/SUBJ  Patrol Request  43.0432  -87.9463
# 183642413-Patrol Request   PROPERTY DAMAGE  Patrol Request      NaN       NaN
# 190012848-Patrol Request   PROPERTY DAMAGE  Patrol Request      NaN       NaN
# 190081253-Patrol Request       ENTRY AUTOS  Patrol Request      NaN       NaN
# 190102066-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 190111745-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 190121639-Patrol Request   PROPERTY DAMAGE  Patrol Request      NaN       NaN
# 190162615-Patrol Request    FAMILY TROUBLE  Patrol Request   43.021  -87.9487
# 190172008-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 190180977-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 190221662-Patrol Request             THEFT  Patrol Request  43.0113  -87.9584
# 190231515-Patrol Request       TRBL W/SUBJ  Patrol Request      NaN       NaN
# 190320600-Patrol Request             THEFT  Patrol Request      NaN       NaN
# 190420966-Patrol Request   PARKING TROUBLE  Patrol Request  43.0029  -87.9324
# 190441517-Patrol Request   PROPERTY DAMAGE  Patrol Request      NaN       NaN
# 190471231-Patrol Request             ENTRY  Patrol Request      NaN       NaN
# 190502181-Patrol Request    SUSPICIOUS-OTH  Patrol Request  43.0169  -87.9576
#
# [74 rows x 8 columns]

# %%
pd.DataFrame(df['Nature of Call'].unique()).to_csv('natures.csv')

# %%
#addrDict = {'Location': df['Location'].unique(), 'Cleaned Location': '', 'Latitude': '', 'Longitude': ''}
#pd.DataFrame(addrDict).set_index(['Location']).to_csv('addresses.csv')

# %%
len(pd.DataFrame(df['Nature of Call'].unique()))
# Out:
# 214

# %%
df[df['Latitude']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-89cf89870809> in <module>()
# ----> 1 df[df['Latitude'].astype(int) < 40]
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~/.local/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: cannot convert float NaN to integer
