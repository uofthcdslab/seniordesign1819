# %%
import urllib3
from bs4 import BeautifulSoup

# %%
http = urllib3.PoolManager()
url = 'https://itmdapps.milwaukee.gov/MPDCallData/'
response = http.request('GET', url)

soup = BeautifulSoup(response.data, 'lxml')
# Out:
# C:\Users\Benjamin\Anaconda3\lib\site-packages\urllib3\connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
print(soup)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <title>Milwaukee Police Department: Call for Service</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/ItmdScripts/css/redesign.css" rel="stylesheet" type="text/css"/><link href="/ItmdScripts/css/city-various.css" rel="stylesheet" type="text/css"/><script src="/ItmdScripts/js/jquery.min.js"></script><script src="/ItmdScripts/js/message.js"></script><script src="/ItmdScripts/js/mil-default.js"></script>
# </head>
# <body>
# ...

# %%
table_cells = soup.find('tbody').find_all('td')
for table_cell in table_cells:
    strings_to_replace = ['''<td style="border: 1px solid black; border-collapse: collapse;">''','</td>','''<td style="border: 1px solid black; border-collapse: collapse; text-align: center;">''']
    for string in strings_to_replace:
        table_cell = str(table_cell)
        table_cell = table_cell.replace(string, '')
    print(table_cell)
# Out:
# 182431898
# 08/31/2018 04:32:04 PM
# 11400 W SILVER SPRING DR,MKE
# 4
# SPECIAL ASSIGN
# Service in Progress
# 182431897
# 08/31/2018 04:31:43 PM
# 1300 W GREENFIELD AV,MKE
# 2
# INVESTIGATION
# Assignment Completed
# 182431663
# 08/31/2018 04:31:33 PM
# 3050 S 62ND ST,MKE
# 6
# NOTIFICATION
# Advised
# 182431895
# 08/31/2018 04:30:25 PM
# 3626 W FOND DU LAC AV,MKE
# 7
# SPECIAL ASSIGN
# Service in Progress
# 182431894
# 08/31/2018 04:30:24 PM
# 7113 W BECKETT AV,MKE
# 7
# PROBATION/PAROLE
# Service in Progress
# 182431887
# 08/31/2018 04:29:38 PM
# N 20TH ST / W FOND DU LAC AV,MKE
# 3
# ACC PI
# Service in Progress
# 182431886
# 08/31/2018 04:27:25 PM
# 2519 S 8TH ST,MKE
# 2
# SUBJ STOP
# Advised
# 182431874
# 08/31/2018 04:26:48 PM
# 1800 S 30TH ST,MKE
# 2
# CHILD ENTICEMENT
# Service in Progress
# 182431881
# 08/31/2018 04:25:57 PM
# 2305 N PROSPECT AV,MKE
# 1
# BUSINESS CHECK
# Assignment Completed
# 182431880
# 08/31/2018 04:25:47 PM
# 3006 S 27TH ST,MKE
# 6
# RETURN STATION
# ...
